# %% [markdown]
# <a href="https://colab.research.google.com/github/No-Qubit-Left-Behind/Control-Engineering-in-TF/blob/master/AdiabaticControl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Adiabatic Control

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
# %tensorflow_version 2.x
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import time
print(tf.__version__)
# Out:
# 2.2.0-rc2

# %%
class PropagatorVL:
    def __init__(self, input_dim, no_of_steps, delta_t):
        self.delta_t = delta_t
        self.duration = no_of_steps * delta_t
        self.no_of_steps = no_of_steps
        self.initial_state = tf.constant([[1], [0]], dtype = tf.complex128)
        self.target_state = tf.constant([[0], [1]], dtype = tf.complex128)
        self.reg_matrix = tf.constant([[1, 0], [0, 5]], dtype = tf.float64)
        """
            contraction_array determines the neccessity for the extra
            matrix multiplication step in the recursive method self.propagate()
            when the intermediate computation array has length not divisible
            by 2
        """
        self.contraction_array = self.gen_contraction_array(no_of_steps)
        """
            ansatz_basis_matrix performs a transformation to the even/odd
            polynomial basis
        """
        self.ansatz_basis_matrix = self.gen_ansatz_matrix(
            input_dim, no_of_steps, delta_t
        )
        self.I = tf.eye(2, dtype = tf.complex128)
        self.x = tf.constant(
            [[0, 1], [1, 0]], dtype=tf.complex128
        )
        self.y = tf.constant(
            [[0 + 0j, 0 - 1j], [0 + 1j, 0 + 0j]], dtype=tf.complex128
        )
        self.z = tf.constant(
            [[1, 0], [0, -1]], dtype=tf.complex128
        )
        
        """ Van Loan generators for adiabatic control """
        # Hamiltonian
        x_Ham = -2 * np.pi *(0 + 1j) * 0.5 * np.block([
            [self.x.numpy(), np.zeros((2, 2))],
            [np.zeros((2, 2)), self.x.numpy()]          
        ])
        z_Ham = -2 * np.pi *(0 + 1j) * 0.5 * np.block([
            [self.z.numpy(), np.zeros((2, 2))],
            [np.zeros((2, 2)), self.z.numpy()]          
        ])
        # Projector
        I_proj = 0.5 * np.block(
            [[np.zeros((2, 2)), self.I.numpy()],
             [np.zeros((2, 2)), np.zeros((2, 2))]]
        )
        x_proj = 0.5 * np.block(
            [[np.zeros((2, 2)), self.x.numpy()],
             [np.zeros((2, 2)), np.zeros((2, 2))]]
        )
        z_proj = 0.5 * np.block(
            [[np.zeros((2, 2)), self.z.numpy()],
             [np.zeros((2, 2)), np.zeros((2, 2))]]
        )

        self.generators =  tf.stack([
                                     tf.constant(x_Ham, dtype=tf.complex128),
                                     tf.constant(z_Ham, dtype=tf.complex128),
                                     tf.constant(I_proj, dtype=tf.complex128),
                                     tf.constant(x_proj, dtype=tf.complex128),
                                     tf.constant(z_proj, dtype=tf.complex128)
                                     ])

        self.ctrl_amplitudes = tf.Variable(
            tf.zeros([input_dim, 2], dtype=tf.float64), dtype=tf.float64
        )

    @staticmethod
    def gen_contraction_array(no_of_intervals):
        if no_of_intervals > 1:
            return (
                [bool(np.mod(no_of_intervals, 2))] +
                PropagatorVL.gen_contraction_array(
                    np.floor(no_of_intervals / 2)
                )
            )
        return []

    @staticmethod
    def gen_ansatz_matrix(input_dim, output_dim, time_step):
        T = output_dim * time_step
        Rabi_basis = tf.constant(
            [[1 - (1 - 2 * t / T) ** (2 * n)
            for n in range(1, input_dim + 1)]
             for t in np.linspace(0., T, output_dim)],
             dtype = tf.float64
        )
        offset_basis = tf.constant(
            [[(1 - 2 * t / T) ** (2 * n - 1)
            for n in range(1, input_dim + 1)]
             for t in np.linspace(0., T, output_dim)]
            , dtype = tf.float64)
        return [Rabi_basis, offset_basis]

    """
        regularize_amplitudes ensures that no individual amplitude exceeds its
        maximum value
    """
    @staticmethod
    def regularize_amplitudes(amplitudes, reg_matrix):
        tanh_output = tf.math.tanh(amplitudes)
        return tf.linalg.matmul(
            tanh_output, reg_matrix
        )

    """
        return_physical_amplitudes transforms the input array
        self.ctrl_amplitudes into physical control amplitudes
    """    
    def return_physical_amplitudes(self):
        basis = self.ansatz_basis_matrix
        ctrls = self.ctrl_amplitudes
        transformed_Rabi = tf.linalg.matmul(basis[0], ctrls[:, 0:1])
        transformed_offset = tf.linalg.matmul(basis[1], ctrls[:, 1:2])
        transformed_amplitudes = tf.concat(
            [transformed_Rabi, transformed_offset], 1
        )
        regularized_amplitudes = self.regularize_amplitudes(
            transformed_amplitudes, self.reg_matrix
        )
        return regularized_amplitudes
    """
    return_auxiliary_amplitudes outputs all variables needed for the VL 
    generator
    """
    def return_auxiliary_amplitudes(self):
        amplitudes = self.return_physical_amplitudes()
        sgn = tf.math.sign(amplitudes[0, 1])
        normalized_amplitudes = tf.linalg.normalize(
            amplitudes, ord = 'euclidean', axis = 1
        )[0]
        drift_amplitudes = tf.ones((self.no_of_steps, 1), dtype = tf.float64)
        return tf.concat(
            [amplitudes, drift_amplitudes, sgn * normalized_amplitudes], 1
        )


    """
        exponentials() computes a vector matrix exponential after multiplying
        each self.ctrl_amplitudes row with a the vector of matrices in
        self.generators
    """
    def exponentials(self):
        all_amplitudes = self.return_auxiliary_amplitudes()
        exponents = tf.linalg.tensordot(
            tf.cast(all_amplitudes, dtype=tf.complex128),
            self.delta_t * self.generators, 1
        )
        return tf.linalg.expm(exponents)
    
    """
        propagate  computes the final propagator by recursively multiplying
        each odd element in the list of matrices with each even element --
        if the length of the array is not divisible by 2 an extra computation
        step is added
    """
    def propagate(self):
        step_exps = self.exponentials()
        for is_odd in self.contraction_array:
            if is_odd:
                odd_exp = step_exps[-1, :, :]
                step_exps = tf.linalg.matmul(
                    step_exps[1::2, :, :], step_exps[0:-1:2, :, :]
                )
                step_exps = tf.concat([
                    step_exps[0:-1, :, :],
                    [tf.linalg.matmul(odd_exp, step_exps[-1, :, :])]
                ], 0)
            else:
                step_exps = tf.linalg.matmul(
                    step_exps[1::2, :, :], step_exps[0::2, :, :]
                )
        return tf.squeeze(step_exps)

    """
        metrics computes the final state and adiabaticity metrics
    """
    def metrics(self):
        VL_propagator = self.propagate()
        propagator = VL_propagator[0:2, 0:2]
        ad_integral = VL_propagator[0:2, 2:4]
        final_state = tf.linalg.matmul(
            propagator, self.initial_state
        )
        # Infidelity
        infidelity = 1 - tf.math.abs(
            tf.linalg.matmul(
                self.target_state, final_state, adjoint_a = True
            )[0, 0]
        ) ** 2
        # Adiabaticity metric
        adiabaticity = 1 - (1 / self.duration) * tf.linalg.matmul(
            final_state, 
            tf.linalg.matmul(
                ad_integral, self.initial_state
            ),
            adjoint_a = True
        )[0, 0]
        adiabaticity = tf.cast(adiabaticity, dtype = tf.float64)
        return infidelity, adiabaticity
    """
        target computes the final cost function
    """
    def target(self):
        metrics = self.metrics()
        return 0.2 * metrics[0] + 0.8 * metrics[1]

propagatorVL = PropagatorVL(10, 1000, 0.005)

optimizer = tf.keras.optimizers.Adam(0.01)

propagatorVL.ctrl_amplitudes.assign(
    tf.random.uniform([10, 2], -1, 1, dtype=tf.float64)
)

@tf.function
def optimization_step():
    with tf.GradientTape() as tape:
        current_target = propagatorVL.target()
    gradients = tape.gradient(current_target, [propagatorVL.ctrl_amplitudes])
    optimizer.apply_gradients(zip(gradients, [propagatorVL.ctrl_amplitudes]))
    return current_target

steps = range(2000)
for step in steps:
    current_target = optimization_step()
    print('step %2d: target=%2.5f' %
          (step, current_target))
    
final_pulse = propagatorVL.return_physical_amplitudes().numpy()
# Out:
# step  0: target=0.59952
# step  1: target=0.54702
# step  2: target=0.45976
# step  3: target=0.34776
# step  4: target=0.23781
# step  5: target=0.15007
# step  6: target=0.09058
# step  7: target=0.05445
# step  8: target=0.03369
# step  9: target=0.02188
# step 10: target=0.01504
# step 11: target=0.01094
# step 12: target=0.00839
# step 13: target=0.00674
# step 14: target=0.00562
# step 15: target=0.00485
# step 16: target=0.00429
# step 17: target=0.00388
# step 18: target=0.00356
# step 19: target=0.00332
# step 20: target=0.00313
# step 21: target=0.00298
# step 22: target=0.00285
# step 23: target=0.00275
# step 24: target=0.00266
# step 25: target=0.00259
# step 26: target=0.00253
# step 27: target=0.00248
# step 28: target=0.00243
# step 29: target=0.00239
# step 30: target=0.00236
# step 31: target=0.00233
# step 32: target=0.00230
# step 33: target=0.00227
# step 34: target=0.00225
# step 35: target=0.00223
# step 36: target=0.00221
# step 37: target=0.00220
# step 38: target=0.00218
# step 39: target=0.00217
# step 40: target=0.00216
# step 41: target=0.00214
# step 42: target=0.00213
# step 43: target=0.00212
# step 44: target=0.00211
# step 45: target=0.00210
# step 46: target=0.00210
# step 47: target=0.00209
# step 48: target=0.00208
# step 49: target=0.00207
# step 50: target=0.00207
# step 51: target=0.00206
# step 52: target=0.00205
# step 53: target=0.00205
# step 54: target=0.00204
# step 55: target=0.00204
# step 56: target=0.00203
# step 57: target=0.00202
# step 58: target=0.00202
# step 59: target=0.00201
# step 60: target=0.00201
# step 61: target=0.00200
# step 62: target=0.00200
# step 63: target=0.00199
# step 64: target=0.00199
# step 65: target=0.00198
# step 66: target=0.00198
# step 67: target=0.00197
# step 68: target=0.00197
# step 69: target=0.00196
# step 70: target=0.00196
# step 71: target=0.00195
# step 72: target=0.00195
# step 73: target=0.00194
# step 74: target=0.00194
# step 75: target=0.00193
# step 76: target=0.00193
# step 77: target=0.00192
# step 78: target=0.00192
# step 79: target=0.00191
# step 80: target=0.00191
# step 81: target=0.00190
# step 82: target=0.00190
# step 83: target=0.00189
# step 84: target=0.00189
# step 85: target=0.00188
# step 86: target=0.00188
# step 87: target=0.00187
# step 88: target=0.00186
# step 89: target=0.00186
# step 90: target=0.00185
# step 91: target=0.00185
# step 92: target=0.00184
# step 93: target=0.00184
# step 94: target=0.00183
# step 95: target=0.00182
# step 96: target=0.00182
# step 97: target=0.00181
# step 98: target=0.00181
# step 99: target=0.00180
# step 100: target=0.00179
# step 101: target=0.00179
# step 102: target=0.00178
# step 103: target=0.00178
# step 104: target=0.00177
# step 105: target=0.00177
# step 106: target=0.00176
# step 107: target=0.00175
# step 108: target=0.00175
# step 109: target=0.00174
# step 110: target=0.00174
# step 111: target=0.00173
# step 112: target=0.00173
# step 113: target=0.00172
# step 114: target=0.00172
# step 115: target=0.00171
# step 116: target=0.00171
# step 117: target=0.00171
# step 118: target=0.00170
# step 119: target=0.00170
# step 120: target=0.00169
# step 121: target=0.00169
# step 122: target=0.00169
# step 123: target=0.00168
# step 124: target=0.00168
# step 125: target=0.00168
# step 126: target=0.00168
# step 127: target=0.00167
# step 128: target=0.00167
# step 129: target=0.00167
# step 130: target=0.00167
# step 131: target=0.00166
# step 132: target=0.00166
# step 133: target=0.00166
# step 134: target=0.00166
# step 135: target=0.00166
# step 136: target=0.00166
# step 137: target=0.00166
# step 138: target=0.00165
# step 139: target=0.00165
# step 140: target=0.00165
# step 141: target=0.00165
# step 142: target=0.00165
# step 143: target=0.00165
# step 144: target=0.00165
# step 145: target=0.00165
# step 146: target=0.00165
# step 147: target=0.00165
# step 148: target=0.00165
# step 149: target=0.00164
# step 150: target=0.00164
# step 151: target=0.00164
# step 152: target=0.00164
# step 153: target=0.00164
# step 154: target=0.00164
# step 155: target=0.00164
# step 156: target=0.00164
# step 157: target=0.00164
# step 158: target=0.00164
# step 159: target=0.00164
# step 160: target=0.00164
# step 161: target=0.00164
# step 162: target=0.00164
# step 163: target=0.00164
# step 164: target=0.00164
# step 165: target=0.00164
# step 166: target=0.00164
# step 167: target=0.00163
# step 168: target=0.00163
# step 169: target=0.00163
# step 170: target=0.00163
# step 171: target=0.00163
# step 172: target=0.00163
# step 173: target=0.00163
# step 174: target=0.00163
# step 175: target=0.00163
# step 176: target=0.00163
# step 177: target=0.00163
# step 178: target=0.00163
# step 179: target=0.00163
# step 180: target=0.00163
# step 181: target=0.00163
# step 182: target=0.00163
# step 183: target=0.00163
# step 184: target=0.00163
# step 185: target=0.00163
# step 186: target=0.00163
# step 187: target=0.00162
# step 188: target=0.00162
# step 189: target=0.00162
# step 190: target=0.00162
# step 191: target=0.00162
# step 192: target=0.00162
# step 193: target=0.00162
# step 194: target=0.00162
# step 195: target=0.00162
# step 196: target=0.00162
# step 197: target=0.00162
# step 198: target=0.00162
# step 199: target=0.00162
# step 200: target=0.00162
# step 201: target=0.00162
# step 202: target=0.00162
# step 203: target=0.00162
# step 204: target=0.00162
# step 205: target=0.00162
# step 206: target=0.00161
# step 207: target=0.00161
# step 208: target=0.00161
# step 209: target=0.00161
# step 210: target=0.00161
# step 211: target=0.00161
# step 212: target=0.00161
# step 213: target=0.00161
# step 214: target=0.00161
# step 215: target=0.00161
# step 216: target=0.00161
# step 217: target=0.00161
# step 218: target=0.00161
# step 219: target=0.00161
# step 220: target=0.00161
# step 221: target=0.00161
# step 222: target=0.00161
# step 223: target=0.00161
# step 224: target=0.00161
# step 225: target=0.00161
# step 226: target=0.00160
# step 227: target=0.00160
# step 228: target=0.00160
# step 229: target=0.00160
# step 230: target=0.00160
# step 231: target=0.00160
# step 232: target=0.00160
# step 233: target=0.00160
# step 234: target=0.00160
# step 235: target=0.00160
# step 236: target=0.00160
# step 237: target=0.00160
# step 238: target=0.00160
# step 239: target=0.00160
# step 240: target=0.00160
# step 241: target=0.00160
# step 242: target=0.00160
# step 243: target=0.00160
# step 244: target=0.00160
# step 245: target=0.00160
# step 246: target=0.00159
# step 247: target=0.00159
# step 248: target=0.00159
# step 249: target=0.00159
# step 250: target=0.00159
# step 251: target=0.00159
# step 252: target=0.00159
# step 253: target=0.00159
# step 254: target=0.00159
# step 255: target=0.00159
# step 256: target=0.00159
# step 257: target=0.00159
# step 258: target=0.00159
# step 259: target=0.00159
# step 260: target=0.00159
# step 261: target=0.00159
# step 262: target=0.00159
# step 263: target=0.00159
# step 264: target=0.00159
# step 265: target=0.00158
# step 266: target=0.00158
# step 267: target=0.00158
# step 268: target=0.00158
# step 269: target=0.00158
# step 270: target=0.00158
# step 271: target=0.00158
# step 272: target=0.00158
# step 273: target=0.00158
# step 274: target=0.00158
# step 275: target=0.00158
# step 276: target=0.00158
# step 277: target=0.00158
# step 278: target=0.00158
# step 279: target=0.00158
# step 280: target=0.00158
# step 281: target=0.00158
# step 282: target=0.00158
# step 283: target=0.00158
# step 284: target=0.00158
# step 285: target=0.00157
# step 286: target=0.00157
# step 287: target=0.00157
# step 288: target=0.00157
# step 289: target=0.00157
# step 290: target=0.00157
# step 291: target=0.00157
# step 292: target=0.00157
# step 293: target=0.00157
# step 294: target=0.00157
# step 295: target=0.00157
# step 296: target=0.00157
# step 297: target=0.00157
# step 298: target=0.00157
# step 299: target=0.00157
# step 300: target=0.00157
# step 301: target=0.00157
# step 302: target=0.00157
# step 303: target=0.00157
# step 304: target=0.00157
# step 305: target=0.00156
# step 306: target=0.00156
# step 307: target=0.00156
# step 308: target=0.00156
# step 309: target=0.00156
# step 310: target=0.00156
# step 311: target=0.00156
# step 312: target=0.00156
# step 313: target=0.00156
# step 314: target=0.00156
# step 315: target=0.00156
# step 316: target=0.00156
# step 317: target=0.00156
# step 318: target=0.00156
# step 319: target=0.00156
# step 320: target=0.00156
# step 321: target=0.00156
# step 322: target=0.00156
# step 323: target=0.00156
# step 324: target=0.00156
# step 325: target=0.00155
# step 326: target=0.00155
# step 327: target=0.00155
# step 328: target=0.00155
# step 329: target=0.00155
# step 330: target=0.00155
# step 331: target=0.00155
# step 332: target=0.00155
# step 333: target=0.00155
# step 334: target=0.00155
# step 335: target=0.00155
# step 336: target=0.00155
# step 337: target=0.00155
# step 338: target=0.00155
# step 339: target=0.00155
# step 340: target=0.00155
# step 341: target=0.00155
# step 342: target=0.00155
# step 343: target=0.00155
# step 344: target=0.00155
# step 345: target=0.00154
# step 346: target=0.00154
# step 347: target=0.00154
# step 348: target=0.00154
# step 349: target=0.00154
# step 350: target=0.00154
# step 351: target=0.00154
# step 352: target=0.00154
# step 353: target=0.00154
# step 354: target=0.00154
# step 355: target=0.00154
# step 356: target=0.00154
# step 357: target=0.00154
# step 358: target=0.00154
# step 359: target=0.00154
# step 360: target=0.00154
# step 361: target=0.00154
# step 362: target=0.00154
# step 363: target=0.00154
# step 364: target=0.00154
# step 365: target=0.00153
# step 366: target=0.00153
# step 367: target=0.00153
# step 368: target=0.00153
# step 369: target=0.00153
# step 370: target=0.00153
# step 371: target=0.00153
# step 372: target=0.00153
# step 373: target=0.00153
# step 374: target=0.00153
# step 375: target=0.00153
# step 376: target=0.00153
# step 377: target=0.00153
# step 378: target=0.00153
# step 379: target=0.00153
# step 380: target=0.00153
# step 381: target=0.00153
# step 382: target=0.00153
# step 383: target=0.00153
# step 384: target=0.00153
# step 385: target=0.00152
# step 386: target=0.00152
# step 387: target=0.00152
# step 388: target=0.00152
# step 389: target=0.00152
# step 390: target=0.00152
# step 391: target=0.00152
# step 392: target=0.00152
# step 393: target=0.00152
# step 394: target=0.00152
# step 395: target=0.00152
# step 396: target=0.00152
# step 397: target=0.00152
# step 398: target=0.00152
# step 399: target=0.00152
# step 400: target=0.00152
# step 401: target=0.00152
# step 402: target=0.00152
# step 403: target=0.00152
# step 404: target=0.00151
# step 405: target=0.00151
# step 406: target=0.00151
# step 407: target=0.00151
# step 408: target=0.00151
# step 409: target=0.00151
# step 410: target=0.00151
# step 411: target=0.00151
# step 412: target=0.00151
# step 413: target=0.00151
# step 414: target=0.00151
# step 415: target=0.00151
# step 416: target=0.00151
# step 417: target=0.00151
# step 418: target=0.00151
# step 419: target=0.00151
# step 420: target=0.00151
# step 421: target=0.00151
# step 422: target=0.00151
# step 423: target=0.00151
# step 424: target=0.00150
# step 425: target=0.00150
# step 426: target=0.00150
# step 427: target=0.00150
# step 428: target=0.00150
# step 429: target=0.00150
# step 430: target=0.00150
# step 431: target=0.00150
# step 432: target=0.00150
# step 433: target=0.00150
# step 434: target=0.00150
# step 435: target=0.00150
# step 436: target=0.00150
# step 437: target=0.00150
# step 438: target=0.00150
# step 439: target=0.00150
# step 440: target=0.00150
# step 441: target=0.00150
# step 442: target=0.00150
# step 443: target=0.00149
# step 444: target=0.00149
# step 445: target=0.00149
# step 446: target=0.00149
# step 447: target=0.00149
# step 448: target=0.00149
# step 449: target=0.00149
# step 450: target=0.00149
# step 451: target=0.00149
# step 452: target=0.00149
# step 453: target=0.00149
# step 454: target=0.00149
# step 455: target=0.00149
# step 456: target=0.00149
# step 457: target=0.00149
# step 458: target=0.00149
# step 459: target=0.00149
# step 460: target=0.00149
# step 461: target=0.00149
# step 462: target=0.00149
# step 463: target=0.00148
# step 464: target=0.00148
# step 465: target=0.00148
# step 466: target=0.00148
# step 467: target=0.00148
# step 468: target=0.00148
# step 469: target=0.00148
# step 470: target=0.00148
# step 471: target=0.00148
# step 472: target=0.00148
# step 473: target=0.00148
# step 474: target=0.00148
# step 475: target=0.00148
# step 476: target=0.00148
# step 477: target=0.00148
# step 478: target=0.00148
# step 479: target=0.00148
# step 480: target=0.00148
# step 481: target=0.00148
# step 482: target=0.00147
# step 483: target=0.00147
# step 484: target=0.00147
# step 485: target=0.00147
# step 486: target=0.00147
# step 487: target=0.00147
# step 488: target=0.00147
# step 489: target=0.00147
# step 490: target=0.00147
# step 491: target=0.00147
# step 492: target=0.00147
# step 493: target=0.00147
# step 494: target=0.00147
# step 495: target=0.00147
# step 496: target=0.00147
# step 497: target=0.00147
# step 498: target=0.00147
# step 499: target=0.00147
# step 500: target=0.00147
# step 501: target=0.00146
# step 502: target=0.00146
# step 503: target=0.00146
# step 504: target=0.00146
# step 505: target=0.00146
# step 506: target=0.00146
# step 507: target=0.00146
# step 508: target=0.00146
# step 509: target=0.00146
# step 510: target=0.00146
# step 511: target=0.00146
# step 512: target=0.00146
# step 513: target=0.00146
# step 514: target=0.00146
# step 515: target=0.00146
# step 516: target=0.00146
# step 517: target=0.00146
# step 518: target=0.00146
# step 519: target=0.00146
# step 520: target=0.00145
# step 521: target=0.00145
# step 522: target=0.00145
# step 523: target=0.00145
# step 524: target=0.00145
# step 525: target=0.00145
# step 526: target=0.00145
# step 527: target=0.00145
# step 528: target=0.00145
# step 529: target=0.00145
# step 530: target=0.00145
# step 531: target=0.00145
# step 532: target=0.00145
# step 533: target=0.00145
# step 534: target=0.00145
# step 535: target=0.00145
# step 536: target=0.00145
# step 537: target=0.00145
# step 538: target=0.00145
# step 539: target=0.00145
# step 540: target=0.00144
# step 541: target=0.00144
# step 542: target=0.00144
# step 543: target=0.00144
# step 544: target=0.00144
# step 545: target=0.00144
# step 546: target=0.00144
# step 547: target=0.00144
# step 548: target=0.00144
# step 549: target=0.00144
# step 550: target=0.00144
# step 551: target=0.00144
# step 552: target=0.00144
# step 553: target=0.00144
# step 554: target=0.00144
# step 555: target=0.00144
# step 556: target=0.00144
# step 557: target=0.00144
# step 558: target=0.00144
# step 559: target=0.00144
# step 560: target=0.00143
# step 561: target=0.00143
# step 562: target=0.00143
# step 563: target=0.00143
# step 564: target=0.00143
# step 565: target=0.00143
# step 566: target=0.00143
# step 567: target=0.00143
# step 568: target=0.00143
# step 569: target=0.00143
# step 570: target=0.00143
# step 571: target=0.00143
# step 572: target=0.00143
# step 573: target=0.00143
# step 574: target=0.00143
# step 575: target=0.00143
# step 576: target=0.00143
# step 577: target=0.00143
# step 578: target=0.00143
# step 579: target=0.00143
# step 580: target=0.00143
# step 581: target=0.00142
# step 582: target=0.00142
# step 583: target=0.00142
# step 584: target=0.00142
# step 585: target=0.00142
# step 586: target=0.00142
# step 587: target=0.00142
# step 588: target=0.00142
# step 589: target=0.00142
# step 590: target=0.00142
# step 591: target=0.00142
# step 592: target=0.00142
# step 593: target=0.00142
# step 594: target=0.00142
# step 595: target=0.00142
# step 596: target=0.00142
# step 597: target=0.00142
# step 598: target=0.00142
# step 599: target=0.00142
# step 600: target=0.00142
# step 601: target=0.00142
# step 602: target=0.00142
# step 603: target=0.00142
# step 604: target=0.00142
# step 605: target=0.00141
# step 606: target=0.00141
# step 607: target=0.00141
# step 608: target=0.00141
# step 609: target=0.00141
# step 610: target=0.00141
# step 611: target=0.00141
# step 612: target=0.00141
# step 613: target=0.00141
# step 614: target=0.00141
# step 615: target=0.00141
# step 616: target=0.00141
# step 617: target=0.00141
# step 618: target=0.00141
# step 619: target=0.00141
# step 620: target=0.00141
# step 621: target=0.00141
# step 622: target=0.00141
# step 623: target=0.00141
# step 624: target=0.00141
# step 625: target=0.00141
# step 626: target=0.00141
# step 627: target=0.00141
# step 628: target=0.00141
# step 629: target=0.00141
# step 630: target=0.00141
# step 631: target=0.00141
# step 632: target=0.00141
# step 633: target=0.00140
# step 634: target=0.00140
# step 635: target=0.00140
# step 636: target=0.00140
# step 637: target=0.00140
# step 638: target=0.00140
# step 639: target=0.00140
# step 640: target=0.00140
# step 641: target=0.00140
# step 642: target=0.00140
# step 643: target=0.00140
# step 644: target=0.00140
# step 645: target=0.00140
# step 646: target=0.00140
# step 647: target=0.00140
# step 648: target=0.00140
# step 649: target=0.00140
# step 650: target=0.00140
# step 651: target=0.00140
# step 652: target=0.00140
# step 653: target=0.00140
# step 654: target=0.00140
# step 655: target=0.00140
# step 656: target=0.00140
# step 657: target=0.00140
# step 658: target=0.00140
# step 659: target=0.00140
# step 660: target=0.00140
# step 661: target=0.00140
# step 662: target=0.00140
# step 663: target=0.00140
# step 664: target=0.00140
# step 665: target=0.00140
# step 666: target=0.00140
# step 667: target=0.00140
# step 668: target=0.00140
# step 669: target=0.00140
# step 670: target=0.00140
# step 671: target=0.00140
# step 672: target=0.00139
# step 673: target=0.00139
# step 674: target=0.00139
# step 675: target=0.00139
# step 676: target=0.00139
# step 677: target=0.00139
# step 678: target=0.00139
# step 679: target=0.00139
# step 680: target=0.00139
# step 681: target=0.00139
# step 682: target=0.00139
# step 683: target=0.00139
# step 684: target=0.00139
# step 685: target=0.00139
# step 686: target=0.00139
# step 687: target=0.00139
# step 688: target=0.00139
# step 689: target=0.00139
# step 690: target=0.00139
# step 691: target=0.00139
# step 692: target=0.00139
# step 693: target=0.00139
# step 694: target=0.00139
# step 695: target=0.00139
# step 696: target=0.00139
# step 697: target=0.00139
# step 698: target=0.00139
# step 699: target=0.00139
# step 700: target=0.00139
# step 701: target=0.00139
# step 702: target=0.00139
# step 703: target=0.00139
# step 704: target=0.00139
# step 705: target=0.00139
# step 706: target=0.00139
# step 707: target=0.00139
# step 708: target=0.00139
# step 709: target=0.00139
# step 710: target=0.00139
# step 711: target=0.00139
# step 712: target=0.00139
# step 713: target=0.00139
# step 714: target=0.00139
# step 715: target=0.00139
# step 716: target=0.00139
# step 717: target=0.00139
# step 718: target=0.00139
# step 719: target=0.00139
# step 720: target=0.00139
# step 721: target=0.00139
# step 722: target=0.00139
# step 723: target=0.00139
# step 724: target=0.00139
# step 725: target=0.00139
# step 726: target=0.00139
# step 727: target=0.00139
# step 728: target=0.00139
# step 729: target=0.00139
# step 730: target=0.00139
# step 731: target=0.00139
# step 732: target=0.00139
# step 733: target=0.00139
# step 734: target=0.00139
# step 735: target=0.00139
# step 736: target=0.00139
# step 737: target=0.00139
# step 738: target=0.00139
# step 739: target=0.00139
# step 740: target=0.00139
# step 741: target=0.00139
# step 742: target=0.00139
# step 743: target=0.00139
# step 744: target=0.00139
# step 745: target=0.00139
# step 746: target=0.00139
# step 747: target=0.00139
# step 748: target=0.00139
# step 749: target=0.00138
# step 750: target=0.00138
# step 751: target=0.00138
# step 752: target=0.00138
# step 753: target=0.00138
# step 754: target=0.00138
# step 755: target=0.00138
# step 756: target=0.00138
# step 757: target=0.00138
# step 758: target=0.00138
# step 759: target=0.00138
# step 760: target=0.00138
# step 761: target=0.00138
# step 762: target=0.00138
# step 763: target=0.00138
# step 764: target=0.00138
# step 765: target=0.00138
# step 766: target=0.00138
# step 767: target=0.00138
# step 768: target=0.00138
# step 769: target=0.00138
# step 770: target=0.00138
# step 771: target=0.00138
# step 772: target=0.00138
# step 773: target=0.00138
# step 774: target=0.00138
# step 775: target=0.00138
# step 776: target=0.00138
# step 777: target=0.00138
# step 778: target=0.00138
# step 779: target=0.00138
# step 780: target=0.00138
# step 781: target=0.00138
# step 782: target=0.00138
# step 783: target=0.00138
# step 784: target=0.00138
# step 785: target=0.00138
# step 786: target=0.00138
# step 787: target=0.00138
# step 788: target=0.00138
# step 789: target=0.00138
# step 790: target=0.00138
# step 791: target=0.00138
# step 792: target=0.00138
# step 793: target=0.00138
# step 794: target=0.00138
# step 795: target=0.00138
# step 796: target=0.00138
# step 797: target=0.00138
# step 798: target=0.00138
# step 799: target=0.00138
# step 800: target=0.00138
# step 801: target=0.00138
# step 802: target=0.00138
# step 803: target=0.00138
# step 804: target=0.00138
# step 805: target=0.00138
# step 806: target=0.00138
# step 807: target=0.00138
# step 808: target=0.00138
# step 809: target=0.00138
# step 810: target=0.00138
# step 811: target=0.00138
# step 812: target=0.00138
# step 813: target=0.00138
# step 814: target=0.00138
# step 815: target=0.00138
# step 816: target=0.00138
# step 817: target=0.00138
# step 818: target=0.00138
# step 819: target=0.00138
# step 820: target=0.00138
# step 821: target=0.00138
# step 822: target=0.00138
# step 823: target=0.00138
# step 824: target=0.00138
# step 825: target=0.00138
# step 826: target=0.00138
# step 827: target=0.00138
# step 828: target=0.00138
# step 829: target=0.00138
# step 830: target=0.00138
# step 831: target=0.00138
# step 832: target=0.00138
# step 833: target=0.00138
# step 834: target=0.00138
# step 835: target=0.00138
# step 836: target=0.00138
# step 837: target=0.00138
# step 838: target=0.00138
# step 839: target=0.00138
# step 840: target=0.00138
# step 841: target=0.00138
# step 842: target=0.00138
# step 843: target=0.00138
# step 844: target=0.00138
# step 845: target=0.00138
# step 846: target=0.00138
# step 847: target=0.00138
# step 848: target=0.00138
# step 849: target=0.00138
# step 850: target=0.00138
# step 851: target=0.00138
# step 852: target=0.00138
# step 853: target=0.00138
# step 854: target=0.00138
# step 855: target=0.00138
# step 856: target=0.00138
# step 857: target=0.00138
# step 858: target=0.00138
# step 859: target=0.00138
# step 860: target=0.00138
# step 861: target=0.00138
# step 862: target=0.00138
# step 863: target=0.00138
# step 864: target=0.00138
# step 865: target=0.00138
# step 866: target=0.00138
# step 867: target=0.00138
# step 868: target=0.00138
# step 869: target=0.00138
# step 870: target=0.00138
# step 871: target=0.00138
# step 872: target=0.00138
# step 873: target=0.00138
# step 874: target=0.00138
# step 875: target=0.00138
# step 876: target=0.00138
# step 877: target=0.00138
# step 878: target=0.00138
# step 879: target=0.00138
# step 880: target=0.00138
# step 881: target=0.00138
# step 882: target=0.00138
# step 883: target=0.00138
# step 884: target=0.00138
# step 885: target=0.00138
# step 886: target=0.00137
# step 887: target=0.00137
# step 888: target=0.00137
# step 889: target=0.00137
# step 890: target=0.00137
# step 891: target=0.00137
# step 892: target=0.00137
# step 893: target=0.00137
# step 894: target=0.00137
# step 895: target=0.00137
# step 896: target=0.00137
# step 897: target=0.00137
# step 898: target=0.00137
# step 899: target=0.00137
# step 900: target=0.00137
# step 901: target=0.00137
# step 902: target=0.00137
# step 903: target=0.00137
# step 904: target=0.00137
# step 905: target=0.00137
# step 906: target=0.00137
# step 907: target=0.00137
# step 908: target=0.00137
# step 909: target=0.00137
# step 910: target=0.00137
# step 911: target=0.00137
# step 912: target=0.00137
# step 913: target=0.00137
# step 914: target=0.00137
# step 915: target=0.00137
# step 916: target=0.00137
# step 917: target=0.00137
# step 918: target=0.00137
# step 919: target=0.00137
# step 920: target=0.00137
# step 921: target=0.00137
# step 922: target=0.00137
# step 923: target=0.00137
# step 924: target=0.00137
# step 925: target=0.00137
# step 926: target=0.00137
# step 927: target=0.00137
# step 928: target=0.00137
# step 929: target=0.00137
# step 930: target=0.00137
# step 931: target=0.00137
# step 932: target=0.00137
# step 933: target=0.00137
# step 934: target=0.00137
# step 935: target=0.00137
# step 936: target=0.00137
# step 937: target=0.00137
# step 938: target=0.00137
# step 939: target=0.00137
# step 940: target=0.00137
# step 941: target=0.00137
# step 942: target=0.00137
# step 943: target=0.00137
# step 944: target=0.00137
# step 945: target=0.00137
# step 946: target=0.00137
# step 947: target=0.00137
# step 948: target=0.00137
# step 949: target=0.00137
# step 950: target=0.00137
# step 951: target=0.00137
# step 952: target=0.00137
# step 953: target=0.00137
# step 954: target=0.00137
# step 955: target=0.00137
# step 956: target=0.00137
# step 957: target=0.00137
# step 958: target=0.00137
# step 959: target=0.00137
# step 960: target=0.00137
# step 961: target=0.00137
# step 962: target=0.00137
# step 963: target=0.00137
# step 964: target=0.00137
# step 965: target=0.00137
# step 966: target=0.00137
# step 967: target=0.00137
# step 968: target=0.00137
# step 969: target=0.00137
# step 970: target=0.00137
# step 971: target=0.00137
# step 972: target=0.00137
# step 973: target=0.00137
# step 974: target=0.00137
# step 975: target=0.00137
# step 976: target=0.00137
# step 977: target=0.00137
# step 978: target=0.00137
# step 979: target=0.00137
# step 980: target=0.00137
# step 981: target=0.00137
# step 982: target=0.00137
# step 983: target=0.00137
# step 984: target=0.00137
# step 985: target=0.00137
# step 986: target=0.00137
# step 987: target=0.00137
# step 988: target=0.00137
# step 989: target=0.00137
# step 990: target=0.00137
# step 991: target=0.00137
# step 992: target=0.00137
# step 993: target=0.00137
# step 994: target=0.00137
# step 995: target=0.00137
# step 996: target=0.00137
# step 997: target=0.00137
# step 998: target=0.00137
# step 999: target=0.00137
# step 1000: target=0.00137
# step 1001: target=0.00137
# step 1002: target=0.00137
# step 1003: target=0.00137
# step 1004: target=0.00137
# step 1005: target=0.00137
# step 1006: target=0.00137
# step 1007: target=0.00137
# step 1008: target=0.00137
# step 1009: target=0.00137
# step 1010: target=0.00137
# step 1011: target=0.00137
# step 1012: target=0.00137
# step 1013: target=0.00137
# step 1014: target=0.00137
# step 1015: target=0.00137
# step 1016: target=0.00137
# step 1017: target=0.00137
# step 1018: target=0.00137
# step 1019: target=0.00137
# step 1020: target=0.00137
# step 1021: target=0.00137
# step 1022: target=0.00137
# step 1023: target=0.00137
# step 1024: target=0.00137
# step 1025: target=0.00137
# step 1026: target=0.00137
# step 1027: target=0.00137
# step 1028: target=0.00137
# step 1029: target=0.00137
# step 1030: target=0.00137
# step 1031: target=0.00137
# step 1032: target=0.00137
# step 1033: target=0.00137
# step 1034: target=0.00137
# step 1035: target=0.00137
# step 1036: target=0.00137
# step 1037: target=0.00137
# step 1038: target=0.00137
# step 1039: target=0.00137
# step 1040: target=0.00137
# step 1041: target=0.00137
# step 1042: target=0.00137
# step 1043: target=0.00137
# step 1044: target=0.00137
# step 1045: target=0.00137
# step 1046: target=0.00137
# step 1047: target=0.00137
# step 1048: target=0.00137
# step 1049: target=0.00137
# step 1050: target=0.00137
# step 1051: target=0.00136
# step 1052: target=0.00136
# step 1053: target=0.00136
# step 1054: target=0.00136
# step 1055: target=0.00136
# step 1056: target=0.00136
# step 1057: target=0.00136
# step 1058: target=0.00136
# step 1059: target=0.00136
# step 1060: target=0.00136
# step 1061: target=0.00136
# step 1062: target=0.00136
# step 1063: target=0.00136
# step 1064: target=0.00136
# step 1065: target=0.00136
# step 1066: target=0.00136
# step 1067: target=0.00136
# step 1068: target=0.00136
# step 1069: target=0.00136
# step 1070: target=0.00136
# step 1071: target=0.00136
# step 1072: target=0.00136
# step 1073: target=0.00136
# step 1074: target=0.00136
# step 1075: target=0.00136
# step 1076: target=0.00136
# step 1077: target=0.00136
# step 1078: target=0.00136
# step 1079: target=0.00136
# step 1080: target=0.00136
# step 1081: target=0.00136
# step 1082: target=0.00136
# step 1083: target=0.00136
# step 1084: target=0.00136
# step 1085: target=0.00136
# step 1086: target=0.00136
# step 1087: target=0.00136
# step 1088: target=0.00136
# step 1089: target=0.00136
# step 1090: target=0.00136
# step 1091: target=0.00136
# step 1092: target=0.00136
# step 1093: target=0.00136
# step 1094: target=0.00136
# step 1095: target=0.00136
# step 1096: target=0.00136
# step 1097: target=0.00136
# step 1098: target=0.00136
# step 1099: target=0.00136
# step 1100: target=0.00136
# step 1101: target=0.00136
# step 1102: target=0.00136
# step 1103: target=0.00136
# step 1104: target=0.00136
# step 1105: target=0.00136
# step 1106: target=0.00136
# step 1107: target=0.00136
# step 1108: target=0.00136
# step 1109: target=0.00136
# step 1110: target=0.00136
# step 1111: target=0.00136
# step 1112: target=0.00136
# step 1113: target=0.00136
# step 1114: target=0.00136
# step 1115: target=0.00136
# step 1116: target=0.00136
# step 1117: target=0.00136
# step 1118: target=0.00136
# step 1119: target=0.00136
# step 1120: target=0.00136
# step 1121: target=0.00136
# step 1122: target=0.00136
# step 1123: target=0.00136
# step 1124: target=0.00136
# step 1125: target=0.00136
# step 1126: target=0.00136
# step 1127: target=0.00136
# step 1128: target=0.00136
# step 1129: target=0.00136
# step 1130: target=0.00136
# step 1131: target=0.00136
# step 1132: target=0.00136
# step 1133: target=0.00136
# step 1134: target=0.00136
# step 1135: target=0.00136
# step 1136: target=0.00136
# step 1137: target=0.00136
# step 1138: target=0.00136
# step 1139: target=0.00136
# step 1140: target=0.00136
# step 1141: target=0.00136
# step 1142: target=0.00136
# step 1143: target=0.00136
# step 1144: target=0.00136
# step 1145: target=0.00136
# step 1146: target=0.00136
# step 1147: target=0.00136
# step 1148: target=0.00136
# step 1149: target=0.00136
# step 1150: target=0.00136
# step 1151: target=0.00136
# step 1152: target=0.00136
# step 1153: target=0.00136
# step 1154: target=0.00136
# step 1155: target=0.00136
# step 1156: target=0.00136
# step 1157: target=0.00136
# step 1158: target=0.00136
# step 1159: target=0.00136
# step 1160: target=0.00136
# step 1161: target=0.00136
# step 1162: target=0.00136
# step 1163: target=0.00136
# step 1164: target=0.00136
# step 1165: target=0.00136
# step 1166: target=0.00136
# step 1167: target=0.00136
# step 1168: target=0.00136
# step 1169: target=0.00136
# step 1170: target=0.00136
# step 1171: target=0.00136
# step 1172: target=0.00136
# step 1173: target=0.00136
# step 1174: target=0.00136
# step 1175: target=0.00136
# step 1176: target=0.00136
# step 1177: target=0.00136
# step 1178: target=0.00136
# step 1179: target=0.00136
# step 1180: target=0.00136
# step 1181: target=0.00136
# step 1182: target=0.00136
# step 1183: target=0.00136
# step 1184: target=0.00136
# step 1185: target=0.00136
# step 1186: target=0.00136
# step 1187: target=0.00136
# step 1188: target=0.00136
# step 1189: target=0.00136
# step 1190: target=0.00136
# step 1191: target=0.00136
# step 1192: target=0.00136
# step 1193: target=0.00136
# step 1194: target=0.00136
# step 1195: target=0.00136
# step 1196: target=0.00136
# step 1197: target=0.00136
# step 1198: target=0.00136
# step 1199: target=0.00136
# step 1200: target=0.00136
# step 1201: target=0.00136
# step 1202: target=0.00136
# step 1203: target=0.00136
# step 1204: target=0.00136
# step 1205: target=0.00136
# step 1206: target=0.00136
# step 1207: target=0.00136
# step 1208: target=0.00136
# step 1209: target=0.00136
# step 1210: target=0.00136
# step 1211: target=0.00136
# step 1212: target=0.00136
# step 1213: target=0.00136
# step 1214: target=0.00136
# step 1215: target=0.00136
# step 1216: target=0.00136
# step 1217: target=0.00136
# step 1218: target=0.00136
# step 1219: target=0.00136
# step 1220: target=0.00136
# step 1221: target=0.00136
# step 1222: target=0.00136
# step 1223: target=0.00136
# step 1224: target=0.00136
# step 1225: target=0.00136
# step 1226: target=0.00136
# step 1227: target=0.00136
# step 1228: target=0.00136
# step 1229: target=0.00136
# step 1230: target=0.00136
# step 1231: target=0.00136
# step 1232: target=0.00136
# step 1233: target=0.00136
# step 1234: target=0.00136
# step 1235: target=0.00136
# step 1236: target=0.00136
# step 1237: target=0.00136
# step 1238: target=0.00136
# step 1239: target=0.00136
# step 1240: target=0.00136
# step 1241: target=0.00136
# step 1242: target=0.00136
# step 1243: target=0.00136
# step 1244: target=0.00136
# step 1245: target=0.00136
# step 1246: target=0.00136
# step 1247: target=0.00136
# step 1248: target=0.00136
# step 1249: target=0.00136
# step 1250: target=0.00136
# step 1251: target=0.00135
# step 1252: target=0.00135
# step 1253: target=0.00135
# step 1254: target=0.00135
# step 1255: target=0.00135
# step 1256: target=0.00135
# step 1257: target=0.00135
# step 1258: target=0.00135
# step 1259: target=0.00135
# step 1260: target=0.00135
# step 1261: target=0.00135
# step 1262: target=0.00135
# step 1263: target=0.00135
# step 1264: target=0.00135
# step 1265: target=0.00135
# step 1266: target=0.00135
# step 1267: target=0.00135
# step 1268: target=0.00135
# step 1269: target=0.00135
# step 1270: target=0.00135
# step 1271: target=0.00135
# step 1272: target=0.00135
# step 1273: target=0.00135
# step 1274: target=0.00135
# step 1275: target=0.00135
# step 1276: target=0.00135
# step 1277: target=0.00135
# step 1278: target=0.00135
# step 1279: target=0.00135
# step 1280: target=0.00135
# step 1281: target=0.00135
# step 1282: target=0.00135
# step 1283: target=0.00135
# step 1284: target=0.00135
# step 1285: target=0.00135
# step 1286: target=0.00135
# step 1287: target=0.00135
# step 1288: target=0.00135
# step 1289: target=0.00135
# step 1290: target=0.00135
# step 1291: target=0.00135
# step 1292: target=0.00135
# step 1293: target=0.00135
# step 1294: target=0.00135
# step 1295: target=0.00135
# step 1296: target=0.00135
# step 1297: target=0.00135
# step 1298: target=0.00135
# step 1299: target=0.00135
# step 1300: target=0.00135
# step 1301: target=0.00135
# step 1302: target=0.00135
# step 1303: target=0.00135
# step 1304: target=0.00135
# step 1305: target=0.00135
# step 1306: target=0.00135
# step 1307: target=0.00135
# step 1308: target=0.00135
# step 1309: target=0.00135
# step 1310: target=0.00135
# step 1311: target=0.00135
# step 1312: target=0.00135
# step 1313: target=0.00135
# step 1314: target=0.00135
# step 1315: target=0.00135
# step 1316: target=0.00135
# step 1317: target=0.00135
# step 1318: target=0.00135
# step 1319: target=0.00135
# step 1320: target=0.00135
# step 1321: target=0.00135
# step 1322: target=0.00135
# step 1323: target=0.00135
# step 1324: target=0.00135
# step 1325: target=0.00135
# step 1326: target=0.00135
# step 1327: target=0.00135
# step 1328: target=0.00135
# step 1329: target=0.00135
# step 1330: target=0.00135
# step 1331: target=0.00135
# step 1332: target=0.00135
# step 1333: target=0.00135
# step 1334: target=0.00135
# step 1335: target=0.00135
# step 1336: target=0.00135
# step 1337: target=0.00135
# step 1338: target=0.00135
# step 1339: target=0.00135
# step 1340: target=0.00135
# step 1341: target=0.00135
# step 1342: target=0.00135
# step 1343: target=0.00135
# step 1344: target=0.00135
# step 1345: target=0.00135
# step 1346: target=0.00135
# step 1347: target=0.00135
# step 1348: target=0.00135
# step 1349: target=0.00135
# step 1350: target=0.00135
# step 1351: target=0.00135
# step 1352: target=0.00135
# step 1353: target=0.00135
# step 1354: target=0.00135
# step 1355: target=0.00135
# step 1356: target=0.00135
# step 1357: target=0.00135
# step 1358: target=0.00135
# step 1359: target=0.00135
# step 1360: target=0.00135
# step 1361: target=0.00135
# step 1362: target=0.00135
# step 1363: target=0.00135
# step 1364: target=0.00135
# step 1365: target=0.00135
# step 1366: target=0.00135
# step 1367: target=0.00135
# step 1368: target=0.00135
# step 1369: target=0.00135
# step 1370: target=0.00135
# step 1371: target=0.00135
# step 1372: target=0.00135
# step 1373: target=0.00135
# step 1374: target=0.00135
# step 1375: target=0.00135
# step 1376: target=0.00135
# step 1377: target=0.00135
# step 1378: target=0.00135
# step 1379: target=0.00135
# step 1380: target=0.00135
# step 1381: target=0.00135
# step 1382: target=0.00135
# step 1383: target=0.00135
# step 1384: target=0.00135
# step 1385: target=0.00135
# step 1386: target=0.00135
# step 1387: target=0.00135
# step 1388: target=0.00135
# step 1389: target=0.00135
# step 1390: target=0.00135
# step 1391: target=0.00135
# step 1392: target=0.00135
# step 1393: target=0.00135
# step 1394: target=0.00135
# step 1395: target=0.00135
# step 1396: target=0.00135
# step 1397: target=0.00135
# step 1398: target=0.00135
# step 1399: target=0.00135
# step 1400: target=0.00135
# step 1401: target=0.00135
# step 1402: target=0.00135
# step 1403: target=0.00135
# step 1404: target=0.00135
# step 1405: target=0.00135
# step 1406: target=0.00135
# step 1407: target=0.00135
# step 1408: target=0.00135
# step 1409: target=0.00135
# step 1410: target=0.00135
# step 1411: target=0.00135
# step 1412: target=0.00135
# step 1413: target=0.00135
# step 1414: target=0.00135
# step 1415: target=0.00135
# step 1416: target=0.00135
# step 1417: target=0.00135
# step 1418: target=0.00135
# step 1419: target=0.00135
# step 1420: target=0.00135
# step 1421: target=0.00135
# step 1422: target=0.00135
# step 1423: target=0.00135
# step 1424: target=0.00135
# step 1425: target=0.00135
# step 1426: target=0.00135
# step 1427: target=0.00135
# step 1428: target=0.00135
# step 1429: target=0.00135
# step 1430: target=0.00135
# step 1431: target=0.00135
# step 1432: target=0.00135
# step 1433: target=0.00135
# step 1434: target=0.00135
# step 1435: target=0.00135
# step 1436: target=0.00135
# step 1437: target=0.00135
# step 1438: target=0.00135
# step 1439: target=0.00135
# step 1440: target=0.00135
# step 1441: target=0.00135
# step 1442: target=0.00135
# step 1443: target=0.00135
# step 1444: target=0.00135
# step 1445: target=0.00135
# step 1446: target=0.00135
# step 1447: target=0.00135
# step 1448: target=0.00135
# step 1449: target=0.00135
# step 1450: target=0.00135
# step 1451: target=0.00135
# step 1452: target=0.00135
# step 1453: target=0.00135
# step 1454: target=0.00135
# step 1455: target=0.00135
# step 1456: target=0.00135
# step 1457: target=0.00135
# step 1458: target=0.00135
# step 1459: target=0.00135
# step 1460: target=0.00135
# step 1461: target=0.00135
# step 1462: target=0.00135
# step 1463: target=0.00135
# step 1464: target=0.00135
# step 1465: target=0.00135
# step 1466: target=0.00135
# step 1467: target=0.00135
# step 1468: target=0.00135
# step 1469: target=0.00135
# step 1470: target=0.00135
# step 1471: target=0.00135
# step 1472: target=0.00135
# step 1473: target=0.00135
# step 1474: target=0.00135
# step 1475: target=0.00135
# step 1476: target=0.00135
# step 1477: target=0.00135
# step 1478: target=0.00135
# step 1479: target=0.00135
# step 1480: target=0.00135
# step 1481: target=0.00135
# step 1482: target=0.00135
# step 1483: target=0.00135
# step 1484: target=0.00135
# step 1485: target=0.00135
# step 1486: target=0.00135
# step 1487: target=0.00135
# step 1488: target=0.00135
# step 1489: target=0.00135
# step 1490: target=0.00135
# step 1491: target=0.00135
# step 1492: target=0.00135
# step 1493: target=0.00135
# step 1494: target=0.00135
# step 1495: target=0.00135
# step 1496: target=0.00135
# step 1497: target=0.00135
# step 1498: target=0.00135
# step 1499: target=0.00134
# step 1500: target=0.00134
# step 1501: target=0.00134
# step 1502: target=0.00134
# step 1503: target=0.00134
# step 1504: target=0.00134
# step 1505: target=0.00134
# step 1506: target=0.00134
# step 1507: target=0.00134
# step 1508: target=0.00134
# step 1509: target=0.00134
# step 1510: target=0.00134
# step 1511: target=0.00134
# step 1512: target=0.00134
# step 1513: target=0.00134
# step 1514: target=0.00134
# step 1515: target=0.00134
# step 1516: target=0.00134
# step 1517: target=0.00134
# step 1518: target=0.00134
# step 1519: target=0.00134
# step 1520: target=0.00134
# step 1521: target=0.00134
# step 1522: target=0.00134
# step 1523: target=0.00134
# step 1524: target=0.00134
# step 1525: target=0.00134
# step 1526: target=0.00134
# step 1527: target=0.00134
# step 1528: target=0.00134
# step 1529: target=0.00134
# step 1530: target=0.00134
# step 1531: target=0.00134
# step 1532: target=0.00134
# step 1533: target=0.00134
# step 1534: target=0.00134
# step 1535: target=0.00134
# step 1536: target=0.00134
# step 1537: target=0.00134
# step 1538: target=0.00134
# step 1539: target=0.00134
# step 1540: target=0.00134
# step 1541: target=0.00134
# step 1542: target=0.00134
# step 1543: target=0.00134
# step 1544: target=0.00134
# step 1545: target=0.00134
# step 1546: target=0.00134
# step 1547: target=0.00134
# step 1548: target=0.00134
# step 1549: target=0.00134
# step 1550: target=0.00134
# step 1551: target=0.00134
# step 1552: target=0.00134
# step 1553: target=0.00134
# step 1554: target=0.00134
# step 1555: target=0.00134
# step 1556: target=0.00134
# step 1557: target=0.00134
# step 1558: target=0.00134
# step 1559: target=0.00134
# step 1560: target=0.00134
# step 1561: target=0.00134
# step 1562: target=0.00134
# step 1563: target=0.00134
# step 1564: target=0.00134
# step 1565: target=0.00134
# step 1566: target=0.00134
# step 1567: target=0.00134
# step 1568: target=0.00134
# step 1569: target=0.00134
# step 1570: target=0.00134
# step 1571: target=0.00134
# step 1572: target=0.00134
# step 1573: target=0.00134
# step 1574: target=0.00134
# step 1575: target=0.00134
# step 1576: target=0.00134
# step 1577: target=0.00134
# step 1578: target=0.00134
# step 1579: target=0.00134
# step 1580: target=0.00134
# step 1581: target=0.00134
# step 1582: target=0.00134
# step 1583: target=0.00134
# step 1584: target=0.00134
# step 1585: target=0.00134
# step 1586: target=0.00134
# step 1587: target=0.00134
# step 1588: target=0.00134
# step 1589: target=0.00134
# step 1590: target=0.00134
# step 1591: target=0.00134
# step 1592: target=0.00134
# step 1593: target=0.00134
# step 1594: target=0.00134
# step 1595: target=0.00134
# step 1596: target=0.00134
# step 1597: target=0.00134
# step 1598: target=0.00134
# step 1599: target=0.00134
# step 1600: target=0.00134
# step 1601: target=0.00134
# step 1602: target=0.00134
# step 1603: target=0.00134
# step 1604: target=0.00134
# step 1605: target=0.00134
# step 1606: target=0.00134
# step 1607: target=0.00134
# step 1608: target=0.00134
# step 1609: target=0.00134
# step 1610: target=0.00134
# step 1611: target=0.00134
# step 1612: target=0.00134
# step 1613: target=0.00134
# step 1614: target=0.00134
# step 1615: target=0.00134
# step 1616: target=0.00134
# step 1617: target=0.00134
# step 1618: target=0.00134
# step 1619: target=0.00134
# step 1620: target=0.00134
# step 1621: target=0.00134
# step 1622: target=0.00134
# step 1623: target=0.00134
# step 1624: target=0.00134
# step 1625: target=0.00134
# step 1626: target=0.00134
# step 1627: target=0.00134
# step 1628: target=0.00134
# step 1629: target=0.00134
# step 1630: target=0.00134
# step 1631: target=0.00134
# step 1632: target=0.00134
# step 1633: target=0.00134
# step 1634: target=0.00134
# step 1635: target=0.00134
# step 1636: target=0.00134
# step 1637: target=0.00134
# step 1638: target=0.00134
# step 1639: target=0.00134
# step 1640: target=0.00134
# step 1641: target=0.00134
# step 1642: target=0.00134
# step 1643: target=0.00134
# step 1644: target=0.00134
# step 1645: target=0.00134
# step 1646: target=0.00134
# step 1647: target=0.00134
# step 1648: target=0.00134
# step 1649: target=0.00134
# step 1650: target=0.00134
# step 1651: target=0.00134
# step 1652: target=0.00134
# step 1653: target=0.00134
# step 1654: target=0.00134
# step 1655: target=0.00134
# step 1656: target=0.00134
# step 1657: target=0.00134
# step 1658: target=0.00134
# step 1659: target=0.00134
# step 1660: target=0.00134
# step 1661: target=0.00134
# step 1662: target=0.00134
# step 1663: target=0.00134
# step 1664: target=0.00134
# step 1665: target=0.00134
# step 1666: target=0.00134
# step 1667: target=0.00134
# step 1668: target=0.00134
# step 1669: target=0.00134
# step 1670: target=0.00134
# step 1671: target=0.00134
# step 1672: target=0.00134
# step 1673: target=0.00134
# step 1674: target=0.00134
# step 1675: target=0.00134
# step 1676: target=0.00134
# step 1677: target=0.00134
# step 1678: target=0.00134
# step 1679: target=0.00134
# step 1680: target=0.00134
# step 1681: target=0.00134
# step 1682: target=0.00134
# step 1683: target=0.00134
# step 1684: target=0.00134
# step 1685: target=0.00134
# step 1686: target=0.00134
# step 1687: target=0.00134
# step 1688: target=0.00134
# step 1689: target=0.00134
# step 1690: target=0.00134
# step 1691: target=0.00134
# step 1692: target=0.00134
# step 1693: target=0.00134
# step 1694: target=0.00134
# step 1695: target=0.00134
# step 1696: target=0.00134
# step 1697: target=0.00134
# step 1698: target=0.00134
# step 1699: target=0.00134
# step 1700: target=0.00134
# step 1701: target=0.00134
# step 1702: target=0.00134
# step 1703: target=0.00134
# step 1704: target=0.00134
# step 1705: target=0.00134
# step 1706: target=0.00134
# step 1707: target=0.00134
# step 1708: target=0.00134
# step 1709: target=0.00134
# step 1710: target=0.00134
# step 1711: target=0.00134
# step 1712: target=0.00134
# step 1713: target=0.00134
# step 1714: target=0.00134
# step 1715: target=0.00134
# step 1716: target=0.00134
# step 1717: target=0.00134
# step 1718: target=0.00134
# step 1719: target=0.00134
# step 1720: target=0.00134
# step 1721: target=0.00134
# step 1722: target=0.00134
# step 1723: target=0.00134
# step 1724: target=0.00134
# step 1725: target=0.00134
# step 1726: target=0.00134
# step 1727: target=0.00134
# step 1728: target=0.00134
# step 1729: target=0.00134
# step 1730: target=0.00134
# step 1731: target=0.00134
# step 1732: target=0.00134
# step 1733: target=0.00134
# step 1734: target=0.00134
# step 1735: target=0.00134
# step 1736: target=0.00134
# step 1737: target=0.00134
# step 1738: target=0.00134
# step 1739: target=0.00134
# step 1740: target=0.00134
# step 1741: target=0.00134
# step 1742: target=0.00134
# step 1743: target=0.00134
# step 1744: target=0.00134
# step 1745: target=0.00134
# step 1746: target=0.00134
# step 1747: target=0.00134
# step 1748: target=0.00134
# step 1749: target=0.00134
# step 1750: target=0.00134
# step 1751: target=0.00134
# step 1752: target=0.00134
# step 1753: target=0.00134
# step 1754: target=0.00134
# step 1755: target=0.00134
# step 1756: target=0.00134
# step 1757: target=0.00134
# step 1758: target=0.00134
# step 1759: target=0.00134
# step 1760: target=0.00134
# step 1761: target=0.00134
# step 1762: target=0.00134
# step 1763: target=0.00134
# step 1764: target=0.00134
# step 1765: target=0.00134
# step 1766: target=0.00134
# step 1767: target=0.00134
# step 1768: target=0.00134
# step 1769: target=0.00134
# step 1770: target=0.00134
# step 1771: target=0.00134
# step 1772: target=0.00134
# step 1773: target=0.00134
# step 1774: target=0.00134
# step 1775: target=0.00134
# step 1776: target=0.00134
# step 1777: target=0.00134
# step 1778: target=0.00134
# step 1779: target=0.00134
# step 1780: target=0.00134
# step 1781: target=0.00134
# step 1782: target=0.00134
# step 1783: target=0.00134
# step 1784: target=0.00134
# step 1785: target=0.00134
# step 1786: target=0.00134
# step 1787: target=0.00134
# step 1788: target=0.00134
# step 1789: target=0.00134
# step 1790: target=0.00134
# step 1791: target=0.00133
# step 1792: target=0.00133
# step 1793: target=0.00133
# step 1794: target=0.00133
# step 1795: target=0.00133
# step 1796: target=0.00133
# step 1797: target=0.00133
# step 1798: target=0.00133
# step 1799: target=0.00133
# step 1800: target=0.00133
# step 1801: target=0.00133
# step 1802: target=0.00133
# step 1803: target=0.00133
# step 1804: target=0.00133
# step 1805: target=0.00133
# step 1806: target=0.00133
# step 1807: target=0.00133
# step 1808: target=0.00133
# step 1809: target=0.00133
# step 1810: target=0.00133
# step 1811: target=0.00133
# step 1812: target=0.00133
# step 1813: target=0.00133
# step 1814: target=0.00133
# step 1815: target=0.00133
# step 1816: target=0.00133
# step 1817: target=0.00133
# step 1818: target=0.00133
# step 1819: target=0.00133
# step 1820: target=0.00133
# step 1821: target=0.00133
# step 1822: target=0.00133
# step 1823: target=0.00133
# step 1824: target=0.00133
# step 1825: target=0.00133
# step 1826: target=0.00133
# step 1827: target=0.00133
# step 1828: target=0.00133
# step 1829: target=0.00133
# step 1830: target=0.00133
# step 1831: target=0.00133
# step 1832: target=0.00133
# step 1833: target=0.00133
# step 1834: target=0.00133
# step 1835: target=0.00133
# step 1836: target=0.00133
# step 1837: target=0.00133
# step 1838: target=0.00133
# step 1839: target=0.00133
# step 1840: target=0.00133
# step 1841: target=0.00133
# step 1842: target=0.00133
# step 1843: target=0.00133
# step 1844: target=0.00133
# step 1845: target=0.00133
# step 1846: target=0.00133
# step 1847: target=0.00133
# step 1848: target=0.00133
# step 1849: target=0.00133
# step 1850: target=0.00133
# step 1851: target=0.00133
# step 1852: target=0.00133
# step 1853: target=0.00133
# step 1854: target=0.00133
# step 1855: target=0.00133
# step 1856: target=0.00133
# step 1857: target=0.00133
# step 1858: target=0.00133
# step 1859: target=0.00133
# step 1860: target=0.00133
# step 1861: target=0.00133
# step 1862: target=0.00133
# step 1863: target=0.00133
# step 1864: target=0.00133
# step 1865: target=0.00133
# step 1866: target=0.00133
# step 1867: target=0.00133
# step 1868: target=0.00133
# step 1869: target=0.00133
# step 1870: target=0.00133
# step 1871: target=0.00133
# step 1872: target=0.00133
# step 1873: target=0.00133
# step 1874: target=0.00133
# step 1875: target=0.00133
# step 1876: target=0.00133
# step 1877: target=0.00133
# step 1878: target=0.00133
# step 1879: target=0.00133
# step 1880: target=0.00133
# step 1881: target=0.00133
# step 1882: target=0.00133
# step 1883: target=0.00133
# step 1884: target=0.00133
# step 1885: target=0.00133
# step 1886: target=0.00133
# step 1887: target=0.00133
# step 1888: target=0.00133
# step 1889: target=0.00133
# step 1890: target=0.00133
# step 1891: target=0.00133
# step 1892: target=0.00133
# step 1893: target=0.00133
# step 1894: target=0.00133
# step 1895: target=0.00133
# step 1896: target=0.00133
# step 1897: target=0.00133
# step 1898: target=0.00133
# step 1899: target=0.00133
# step 1900: target=0.00133
# step 1901: target=0.00133
# step 1902: target=0.00133
# step 1903: target=0.00133
# step 1904: target=0.00133
# step 1905: target=0.00133
# step 1906: target=0.00133
# step 1907: target=0.00133
# step 1908: target=0.00133
# step 1909: target=0.00133
# step 1910: target=0.00133
# step 1911: target=0.00133
# step 1912: target=0.00133
# step 1913: target=0.00133
# step 1914: target=0.00133
# step 1915: target=0.00133
# step 1916: target=0.00133
# step 1917: target=0.00133
# step 1918: target=0.00133
# step 1919: target=0.00133
# step 1920: target=0.00133
# step 1921: target=0.00133
# step 1922: target=0.00133
# step 1923: target=0.00133
# step 1924: target=0.00133
# step 1925: target=0.00133
# step 1926: target=0.00133
# step 1927: target=0.00133
# step 1928: target=0.00133
# step 1929: target=0.00133
# step 1930: target=0.00133
# step 1931: target=0.00133
# step 1932: target=0.00133
# step 1933: target=0.00133
# step 1934: target=0.00133
# step 1935: target=0.00133
# step 1936: target=0.00133
# step 1937: target=0.00133
# step 1938: target=0.00133
# step 1939: target=0.00133
# step 1940: target=0.00133
# step 1941: target=0.00133
# step 1942: target=0.00133
# step 1943: target=0.00133
# step 1944: target=0.00133
# step 1945: target=0.00133
# step 1946: target=0.00133
# step 1947: target=0.00133
# step 1948: target=0.00133
# step 1949: target=0.00133
# step 1950: target=0.00133
# step 1951: target=0.00133
# step 1952: target=0.00133
# step 1953: target=0.00133
# step 1954: target=0.00133
# step 1955: target=0.00133
# step 1956: target=0.00133
# step 1957: target=0.00133
# step 1958: target=0.00133
# step 1959: target=0.00133
# step 1960: target=0.00133
# step 1961: target=0.00133
# step 1962: target=0.00133
# step 1963: target=0.00133
# step 1964: target=0.00133
# step 1965: target=0.00133
# step 1966: target=0.00133
# step 1967: target=0.00133
# step 1968: target=0.00133
# step 1969: target=0.00133
# step 1970: target=0.00133
# step 1971: target=0.00133
# step 1972: target=0.00133
# step 1973: target=0.00133
# step 1974: target=0.00133
# step 1975: target=0.00133
# step 1976: target=0.00133
# step 1977: target=0.00133
# step 1978: target=0.00133
# step 1979: target=0.00133
# step 1980: target=0.00133
# step 1981: target=0.00133
# step 1982: target=0.00133
# step 1983: target=0.00133
# step 1984: target=0.00133
# step 1985: target=0.00133
# step 1986: target=0.00133
# step 1987: target=0.00133
# step 1988: target=0.00133
# step 1989: target=0.00133
# step 1990: target=0.00133
# step 1991: target=0.00133
# step 1992: target=0.00133
# step 1993: target=0.00133
# step 1994: target=0.00133
# step 1995: target=0.00133
# step 1996: target=0.00133
# step 1997: target=0.00133
# step 1998: target=0.00133
# step 1999: target=0.00133

# %%
fig, (Rabi_fig, offset_fig) = plt.subplots(2, 1, figsize=(10, 15))
Rabi_fig.plot(final_pulse[:,0])
offset_fig.plot(final_pulse[:,1])

# %%
# Final state
print(propagatorVL.metrics()[0].numpy())
# Adiabaticity
print(propagatorVL.metrics()[1].numpy())
# Out:
# 2.9680893919636908e-05
# 0.00165271375195708

# %%
angles = []
exps = propagatorVL.exponentials()
state = propagatorVL.initial_state
for i in range(propagatorVL.no_of_steps):
  state = tf.linalg.matmul(
      exps[i, 0:2, 0:2], state
  )

  sigma_x = tf.linalg.matmul(
      state, tf.linalg.matmul(
          propagatorVL.x, state
      ),
      adjoint_a = True
  )
  sigma_y = tf.linalg.matmul(
      state, tf.linalg.matmul(
          propagatorVL.y, state
      ),
      adjoint_a = True
  )
  sigma_z = tf.linalg.matmul(
      state, tf.linalg.matmul(
          propagatorVL.z, state
      ),
      adjoint_a = True
  )
  sigma = np.ndarray.flatten(
      tf.concat(
          [sigma_x, sigma_y, sigma_z], 0
      ).numpy()
  )

  eff_field = np.array([final_pulse[i, 0], 0, final_pulse[i, 1]])

  angles.append(
      180 - (180 / np.pi) * np.arccos(
          np.dot(eff_field, np.real(sigma))
          / np.linalg.norm(eff_field)
          / np.linalg.norm(sigma)
      )
  )

fig, ax = plt.subplots()
ax.plot(angles)
